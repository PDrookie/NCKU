"""

data_10_epochs = """
Epoch   Training_Loss    Validation_Loss    Rouge1  Rouge2  Rougel  Rougelsum   Gen Len
1   3.274500    3.755440    0.099500    0.012400    0.097500    0.098200    10.806900
2   2.685700    3.705673    0.104900    0.015200    0.101300    0.102400    10.953900
3   2.216100    3.809803    0.095200    0.015100    0.093900    0.095300    10.896300
4   1.793400    4.020584    0.109700    0.010600    0.108000    0.108700    10.734900
5   1.441900    4.191828    0.107700    0.011500    0.104200    0.104900    11.420700
6   1.172700    4.330890    0.100300    0.009600    0.097800    0.098700    11.072000
7   0.945000    4.509830    0.105800    0.010600    0.104600    0.104600    11.147000
8   0.757300    4.578986    0.096700    0.011500    0.095700    0.096000    11.259400
9   0.624500    4.662529    0.101800    0.013400    0.100600    0.101200    11.233400
10  0.531300    4.697747    0.107300    0.011500    0.106000    0.107000    11.250700
"""

data_20_epochs = """
Epoch   Training_Loss    Validation_Loss    Rouge1  Rouge2  Rougel  Rougelsum   Gen Len
1   3.280900    3.761441    0.104400    0.008100    0.103600    0.103900    10.795400
2   2.704100    3.713460    0.095200    0.015200    0.095300    0.094200    10.835700
3   2.245500    3.846405    0.097200    0.014400    0.096500    0.095600    11.025900
4   1.831700    4.038725    0.097800    0.012500    0.097400    0.097500    10.596500
5   1.477900    4.225835    0.090300    0.011300    0.088300    0.088700    11.319900
6   1.201100    4.446683    0.081700    0.006700    0.081600    0.081500    11.069200
7   0.961500    4.629511    0.095900    0.010600    0.094400    0.094900    10.876100
8   0.753800    4.771376    0.110400    0.013000    0.110300    0.109900    11.648400
9   0.592600    4.933805    0.096400    0.014400    0.096000    0.096500    11.714700
10  0.465600    5.037645    0.086500    0.009600    0.086100    0.086100    11.412100
11  0.367300    5.186808    0.104900    0.016000    0.104400    0.104400    11.455300
12  0.293400    5.266717    0.113300    0.012000    0.112200    0.111600    11.380400
13  0.234600    5.411901    0.093600    0.015400    0.092200    0.092700    11.440900
14  0.191200    5.472726    0.108300    0.010800    0.107800    0.107000    11.409200
15  0.156400    5.558627    0.106400    0.009600    0.105900    0.105600    11.377500
16  0.127900    5.616126    0.111800    0.011000    0.111500    0.111300    11.377500
17  0.107800    5.648277    0.105900    0.013900    0.105100    0.104900    11.340100
18  0.089400    5.692005    0.093800    0.007700    0.094100    0.093600    11.158500
19  0.079000    5.732869    0.102800    0.009600    0.102400    0.101900    11.262200
20  0.068600    5.729146    0.090700    0.009600    0.089100    0.089300    11.389000
"""

# 將數據轉換為DataFrame
df_5_epochs = pd.read_csv(StringIO(data_5_epochs), delim_whitespace=True)
df_10_epochs = pd.read_csv(StringIO(data_10_epochs), delim_whitespace=True)
df_20_epochs = pd.read_csv(StringIO(data_20_epochs), delim_whitespace=True)

# 計算每個模型的平均Rouge值
avg_rouge_5_epochs = df_5_epochs[['Rouge1', 'Rouge2', 'Rougel', 'Rougelsum']].mean()
avg_rouge_10_epochs = df_10_epochs[['Rouge1', 'Rouge2', 'Rougel', 'Rougelsum']].mean()
avg_rouge_20_epochs = df_20_epochs[['Rouge1', 'Rouge2', 'Rougel', 'Rougelsum']].mean()

# 繪製柱狀圖
plt.figure(figsize=(8, 4))

bar_width = 0.2
index = range(len(avg_rouge_5_epochs))

plt.bar(index, avg_rouge_5_epochs, bar_width, label='5 epochs')
plt.bar([i + bar_width for i in index], avg_rouge_10_epochs, bar_width, label='10 epochs')
plt.bar([i + bar_width*2 for i in index], avg_rouge_20_epochs, bar_width, label='20 epochs')

plt.xlabel('Metrics')
plt.ylabel('Average Rouge Value')
plt.title('Comparison of Average Rouge Values for Different Epochs')
plt.xticks([i + bar_width for i in index], avg_rouge_5_epochs.index)
plt.legend()
plt.show()

# %% [markdown]
# # GPT2

# %% [markdown]
# ## 5 epochs

# %%
# 你提供的訓練結果文字
data = """
Epo
model')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Rouge

# %%
# 定義數據
data_5_epochs = """
Epoch Training_Loss Validation_Loss Rouge1 Rouge2 Rougel Rougelsum Gen Len
1 2.659800 2.544472 0.126700 0.018100 0.118200 0.118400 160.000000
2 2.549900 2.525031 0.135400 0.016200 0.125500 0.125300 160.000000
3 2.473400 2.512788 0.125800 0.017600 0.118300 0.118300 160.000000
4 2.403400 2.509581 0.132100 0.014000 0.123600 0.124100 160.000000
5 2.358700 2.509190 0.139500 0.019200 0.131900 0.131900 160.000000
"""

data_10_epochs = """
Epoch	Training_Loss	Validation_Loss	Rouge1	Rouge2	Rougel	Rougelsum	Gen Len
1	2.664400	2.550539	0.128600	0.019500	0.120400	0.121000	160.000000
2	2.561300	2.538313	0.141200	0.018500	0.129900	0.131600	160.000000
3	2.489700	2.532714	0.118500	0.017600	0.111500	0.112600	160.000000
4	2.421600	2.530655	0.143800	0.019600	0.134500	0.135300	160.000000
5	2.372600	2.536075	0.147600	0.019800	0.140200	0.141200	160.000000
6	2.323200	2.538116	0.167700	0.030100	0.158100	0.158200	160.000000
7	2.282500	2.540060	0.142500	0.019400	0.133900	0.134900	160.000000
8	2.248600	2.543135	0.144800	0.017900	0.137300	0.138500	160.000000
9	2.211200	2.546599	0.145200	0.019400	0.136500	0.137500	160.000000
10	2.188800	2.552340	0.143300	0.019300	0.135900	0.137000	160.000000
"""

data_20_epochs = """
Epoch	Training_Loss	Validation_Loss	Rouge1	Rouge2	Rougel	Rougelsum	Gen Len
1	2.666800	2.553670	0.131200	0.018000	0.124100	0.123600	160.000000
2	2.567300	2.545133	0.144900	0.020800	0.136100	0.135600	160.000000
3	2.498900	2.542749	0.120000	0.017300	0.114800	0.114000	160.000000
4	2.433400	2.544743	0.135600	0.021100	0.129100	0.128800	160.000000
5	2.386200	2.553188	0.145800	0.019200	0.137500	0.136400	160.000000
6	2.338400	2.560650	0.159200	0.027200	0.151300	0.150700	160.000000
7	2.297400	2.566899	0.136500	0.017400	0.126400	0.125700	160.000000
8	2.262200	2.571842	0.141200	0.019400	0.131700	0.130600	160.000000
9	2.221800	2.585341	0.136000	0.018100	0.129100	0.127800	160.000000
10	2.193900	2.598248	0.145000	0.023800	0.135600	0.134700	160.000000
11	2.160400	2.598881	0.135100	0.019200	0.127900	0.127000	160.000000
12	2.139900	2.611165	0.141500	0.023200	0.132100	0.132200	160.000000
13	2.107700	2.620880	0.138800	0.018400	0.131400	0.130200	160.000000
14	2.084400	2.621657	0.147600	0.017500	0.140800	0.140200	160.000000
15	2.060900	2.634803	0.141900	0.014500	0.132100	0.131000	160.000000
16	2.042000	2.641220	0.140100	0.018700	0.131000	0.130200	160.000000
17	2.018100	2.645889	0.144500	0.016700	0.133300	0.133000	160.000000
18	2.000700	2.647727	0.146700	0.016400	0.134200	0.133700	160.000000
19	1.989100	2.655769	0.142100	0.016600	0.131000	0.130800	160.000000
20	1.976300	2.661085	0.144200	0.016700	0.133400	0.132900	160.000000
"""

# 將數據轉換為DataFrame
df_5_epochs = pd.read_csv(StringIO(data_5_epochs), delim_whitespace=True)
df_10_epochs = pd.read_csv(StringIO(data_10_epochs), delim_whitespace=True)
df_20_epochs = pd.read_csv(StringIO(data_20_epochs), delim_whitespace=True)

# 計算每個模型的平均Rouge值
avg_rouge_5_epochs = df_5_epochs[['Rouge1', 'Rouge2', 'Rougel', 'Rougelsum']].mean()
avg_rouge_10_epochs = df_10_epochs[['Rouge1', 'Rouge2', 'Rougel', 'Rougelsum']].mean()
avg_rouge_20_epochs = df_20_epochs[['Rouge1', 'Rouge2', 'Rougel', 'Rougelsum']].mean()

# 繪製柱狀圖
plt.figure(figsize=(8, 4))

bar_width = 0.2
index = range(len(avg_rouge_5_epochs))

plt.bar(index, avg_rouge_5_epochs, bar_width, label='5 epochs')
plt.bar([i + bar_width for i in index], avg_rouge_10_epochs, bar_width, label='10 epochs')
plt.bar([i + bar_width*2 for i in index], avg_rouge_20_epochs, bar_width, label='20 epochs')

plt.xlabel('Metrics')
plt.ylabel('Average Rouge Value')
plt.title('Comparison of Average Rouge Values for Different Epochs')
plt.xticks([i + bar_width for i in index], avg_rouge_5_epochs.index)
plt.legend()
plt.show()

# %% [markdown]
# # Compare

# %%
# 你提供的訓練結果文字
data = """
Epoch	Training_Loss	Validation_Loss	Rouge1	Rouge2	Rougel	Rougelsum	Gen Len
1	3.704700	4.095170	0.067400	0.019400	0.069800	0.068400	10.476700
2	2.774400	4.210754	0.075600	0.019400	0.079100	0.077900	10.244200
3	1.984200	4.554506	0.082600	0.019400	0.084900	0.084900	10.918600
4	1.420000	4.845899	0.076700	0.027100	0.076700	0.076700	10.814000
5	1.064600	5.004747	0.094200	0.031000	0.097700	0.097700	10.767400
"""

# 將文字轉換為DataFrame
df = pd.read_csv(StringIO(data), delim_whitespace=True)

# 提取Training Loss和Validation Loss的數據
epochs = df['Epoch']
training_loss = df['Training_Loss']
validation_loss = df['Validation_Loss']

# 繪製折線圖
plt.figure(figsize=(5, 3))
plt.plot(epochs, training_loss, label='Training Loss', marker='o')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='o')
plt.title('T5 model')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 你提供的訓練結果文字
data = """
Epoch	Training_Loss	Validation_Loss	Rouge1	Rouge2	Rougel	Rougelsum	Gen Len
1	2.755500	2.652003	0.066200	0.011200	0.066000	0.065400	160.000000
2	2.585200	2.652080	0.088800	0.018800	0.085600	0.084100	160.000000
3	2.452800	2.659922	0.077500	0.015900	0.073000	0.072700	160.000000
4	2.349000	2.671685	0.082000	0.016400	0.079100	0.078900	160.000000
5	2.267200	2.684328	0.075100	0.015800	0.072300	0.072400	160.000000
"""

# 將文字轉換為DataFrame
df = pd.read_csv(StringIO(data), delim_whitespace=True)

# 提取Training Loss和Validation Loss的數據
epochs = df['Epoch']
training_loss = df['Training_Loss']
validation_loss = df['Validation_Loss']

# 繪製折線圖
plt.figure(figsize=(5, 3))
plt.plot(epochs, training_loss, label='Training Loss', marker='o')
plt.plot(epochs, validation_loss, label='Validation Loss', marker='o')
plt.title('GPT2 model')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 定義數據
data_T5 = """
Epoch	Training_Loss	Validation_Loss	Rouge1	Rouge2	Rougel	Rougelsum	Gen Len
1	3.704700	4.095170	0.067400	0.019400	0.069800	0.068400	10.476700
2	2.774400	4.210754	0.075600	0.019400	0.079100	0.077900	10.244200
3	1.984200	4.554506	0.082600	0.019400	0.084900	0.084900	10.918600
4	1.420000	4.845899	0.076700	0.027100	0.076700	0.076700	10.814000
5	1.064600	5.004747	0.094200	0.031000	0.097700	0.097700	10.767400
"""

data_GPT2 = """
Epoch	Training_Loss	Validation_Loss	Rouge1	Rouge2	Rougel	Rougelsum	Gen Len
1	2.755500	2.652003	0.066200	0.011200	0.066000	0.065400	160.000000
2	2.585200	2.652080	0.088800	0.018800	0.085600	0.084100	160.000000
3	2.452800	2.659922	0.077500	0.015900	0.073000	0.072700	160.000000
4	2.349000	2.671685	0.082000	0.016400	0.079100	0.078900	160.000000
5	2.267200	2.684328	0.075100	0.015800	0.072300	0.072400	160.000000
"""


# 將數據轉換為DataFrame
df_T5 = pd.read_csv(StringIO(data_T5), delim_whitespace=True)
df_GPT2 = pd.read_csv(StringIO(data_GPT2), delim_whitespace=True)

# 計算每個模型的平均Rouge值
avg_rouge_T5 = df_T5[['Rouge1', 'Rouge2', 'Rougel', 'Rougelsum']].mean()
avg_rouge_GPT2 = df_GPT2[['Rouge1', 'Rouge2', 'Rougel', 'Rougelsum']].mean()

# 繪製柱狀圖
plt.figure(figsize=(8, 4))

bar_width = 0.2
index = range(len(avg_rouge_5_epochs))

plt.bar(index, avg_rouge_T5, bar_width, label='T5 model')
plt.bar([i + bar_width for i in index], avg_rouge_GPT2, bar_width, label='GPT2 model')

plt.xlabel('Metrics')
plt.ylabel('Average Rouge Value')
plt.title('Comparison of Average Rouge Values for Different Models')
plt.xticks([i + bar_width for i in index], avg_rouge_5_epochs.index)
plt.legend()
plt.show()
